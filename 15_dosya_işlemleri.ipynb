# %%
open("bilgiler.txt","w")
# Out:
# <_io.TextIOWrapper name='bilgiler.txt' mode='w' encoding='cp1254'>

# %%
file = open("bilgiler.txt","w")

# %%
# file.close dosyayı kapatır

# %%
file = open("C:/Users/user/Desktop/bilgileer.txt","w") 
#  masaüstünde  olusturdu

# %%
file = open("bilgiler.txt","w")

# %%
file.write("sukru kocaturk")
# Out:
# 14
