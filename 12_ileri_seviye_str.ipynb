# %%
"phyton".upper() 
#  ifadeyi komple buyuk yazmaya yarar
# Out:
# 'PHYTON'

# %%
'PHYTON'.lower()
#  ifadeyi komple kucuk yazmaya yara
# Out:
# 'phyton'

# %%
"herkes ana baba bacı gardas".replace("a","o")
#  raplace ifadesi iki ifadenin yerini degıstırmeye yarar
# Out:
# 'herkes ono bobo bocı gordos'

# %%
"kunduz".replace("duz","zun")
# Out:
# 'kunzun'

# %%
"phyton".startswith("p") 
# ifade  bişeyle baslıyorsa true baslamıyorsa false
# Out:
# True

# %%
"phyton".endswith("on")
# ifade biseyle bitiuosa true bitmiyosa folsa
# Out:
# True

# %%
liste="phyton proglamlama dili".split(" ")
#  ifadenin her bir elamanını parcalıyor ve liste yapıyor

# %%
print(liste)
# Out:
# ['phyton', 'proglamlama', 'dili']

# %%
"                  phyton                   ".strip()
# Out:
# 'phyton'

# %%
"                  phyton                   ".strip()
# Out:
# 'phyton                   '

# %%
"                  phyton                   ".rstrip()
# Out:
# '                  phyton'

# %%
liste = ["21","02","2014"]

# %%
# join()
# Listenin elemanlarını bir string değeriyle birleştirmemizi sağlar.
"/".join(liste)
# Out:
# '21/02/2014'

# %%
"ada kapısı yandan çarklı".count("a")
# Out:
# 6

# %%
"ada kapısı yandan çarklı".count("a",3)
# Out:
# 4

# %%
# find(x) : x değerini baştan itibaren string içinde arar 
# ve bulursa ilk bulduğu indeksi döndürür. Bulamazsa "-1" değerini verir.
 

# rfind(x) : x değerini sondan itibaren string içinde arar ve
#  bulursa ilk bulduğu indeksi döndürür. Bulamazsa "-1" değerini verir.



"araba".find("r")
# Out:
# 1

# %%
"araba".find("s")
# Out:
# -1

# %%
"araba".rfind("a")
# Out:
# 4

# %%
#  bu metodları ezberlemeye gerek yok
# İşte stringlerin belli başlı metodları bunlardır. 
# Diğer metodları da ihtiyacınız olduğu durumda şu siteye bakarak öğrenebilirsiniz.

# https://www.tutorialspoint.com/python3/python_strings.htm
