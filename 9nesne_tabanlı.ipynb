# %%
class araba():
    renk = "mavi"
    model= "passat"
    beygir= "200"

# %%
araba1= araba

# %%
araba.model
# Out:
# 'passat'

# %%
araba.model
# Out:
# 'passat'

# %%
dir(araba)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'beygir',
#  'model',
#  'renk']

# %%
class araba():
    renk = "mavi"
    model= "passat"
    beygir= "200"

  

    def __init__(self):
        print("init fonksiyonu çağrıldı")

# %%
araba1=araba()
# Out:
# init fonksiyonu çağrıldı

# %%
class araba():

  def __init__(self,model,renk,beygir):
        print("init fonksiyonu çağrıldı")

        self.model= model
        self.renk=  renk
        self.beygir= beygir

# %%
araba1= araba("renualt","mavi","200")
# Out:
# init fonksiyonu çağrıldı

# %%
araba1.model
# Out:
# 'renualt'

# %%
araba1.renk
# Out:
# 'mavi'

# %%
class yazılımcı():
    def __init__(self,adınız,soyadınız,numaranız,maaş,bildiği_diller) :
        self.adınız=adınız
        self.soyadınız= soyadınız
        self.numaranız= numaranız
        self. maaş=maaş
        self.bildiği_diller=bildiği_diller

    def bilgileri_döndür(self):
        print(""" 
        
        yazılımcı objesinin özellikleri:
              
              adınız: {}
              soyadınız={}
              numaranız={}
              maşş= {}
              bildiği_diller={}

              
              
              
              
              
              """.format(self.adınız,self.soyadınız,self.numaranız,self.maaş,self.bildiği_diller))

# %%
yazılım= yazılımcı("şükrü","kocatürk",121212,13000,["java","phyton","c","c++"])

# %%
yazılım.soyadınız
# Out:
# 'kocatürk'

# %%
yazılım.bilgileri_döndür()
# Out:
#
#
#         yazılımcı objesinin özellikleri:
#
#               adınız: şükrü
#               soyadınız=kocatürk
#               numaranız=121212
#               maşş= 13000
#               bildiği_diller=['java', 'phyton', 'c', 'c++']

# %%
class Yazılımcı():
    
    def __init__(self,isim,soyisim,numara,maaş,diller):
        self.isim = isim
        self.soyisim = soyisim
        self.numara = numara    # Yazılımcı objelerinin özellikleri 
        self.maaş = maaş
        self.diller = diller
    def bilgilerigöster(self):
        print("""
        Çalışan Bilgisi:
        
        İsim :  {}
        
        Soyisim : {}
        
        Şirket Numarası: {}
        
        Maaş :  {}
        
        Diller: {}
        """.format(self.isim,self.soyisim,self.numara,self.maaş,self.diller))
    def dil_ekle(self,yeni_dil):
        print("Dil ekleniyor.")
        self.diller.append(yeni_dil)
    def maas_yukselt(self,zam_miktarı):
        print("Maaş yükseliyor...")
        
        self.maaş += 250

# %%
yazılım= yazılımcı("şükrü","kocatürk",121212,13000,["java","phyton","c","c++"])

# %%
yazılım.bilgileri_döndür()
# Out:
#
#
#         yazılımcı objesinin özellikleri:
#
#               adınız: şükrü
#               soyadınız=kocatürk
#               numaranız=121212
#               maşş= 13000
#               bildiği_diller=['java', 'phyton', 'c', 'c++']

# %%
yazılım.dil("Javascript")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 yazılım.dil("Javascript")
#
# NameError: name 'yazılım' is not defined
