# %%
bin(4)
# Out:
# '0b100'

# %%
#  ikili tabana cevirme (2**0)*(1)+(2**1)*(1)+(2**2)*(0)+(2**3)*(0)+(2**4)*1
bin(19)
# Out:
# '0b10011'

# %%
# hex 16lık tabanda yazmaya yarar
hex(20)
# Out:
# '0x14'

# %%
abs(-4)
#  abs ifadesi mutlak deger almaya yarar
# Out:
# 4

# %%
round(4.5)
#  round sayımızı yuvarlamamızı saglar
# Out:
# 4

# %%
round(1.23454)
# Out:
# 1

# %%
max(3,4)
#  math en buyuk sayıyı almamızı saglar
# Out:
# 4

# %%
min(4,5)
# Out:
# 4

# %%
sum([1,2,3,4,5,6,7,8,9]) 
#  sum fonksiyonuna liste ve demet gondermemiz lazım 
#  sum ifadenin içindeki sayıları toplar ifadenin içinde sayı olmalı
# Out:
# 45

# %%
pow(2,4) 
#  pow üst almaya yarar
# Out:
# 16
