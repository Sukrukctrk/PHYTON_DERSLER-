# %%
"""
banka kodu 

"""
borç_miktarı= int(input("borç miktarınını giriniz"))

if borç_miktarı> 0:


 taksit_sayısı = int(input("kaç taksit yapmak istediğinizi geriniz"))
  


if taksit_sayısı>0:



 
 faiz_miktarı= (taksit_sayısı* borç_miktarı)*(1/100) 

print("ödemeniz gereken  faiz miktarı",faiz_miktarı ," tl")


aylık_tutar= (faiz_miktarı + borç_miktarı) / taksit_sayısı

print( taksit_sayısı," ay boyunca her ay ödemniz gereken faizli tutar", aylık_tutar,"tl 'dir.")
# Out:
# ödemeniz gereken  faiz miktarı 12000.0  tl
# 12  ay boyunca her ay ödemniz gereken faizli tutar 9333.333333333334 tl 'dir.

# %%
# köklü sayı hesabı yapan program

ust_limit= int(input("bir sayı değeri giriniz"))

if ust_limit>0:

    karekok= ust_limit** (1/2)

    print("girdiğiniz ",ust_limit,"sayısının karekökü",karekok,"' dir")


else:
    print("lütfen pozit tam sayı giriniz")
# Out:
# girdiğiniz  10000000 sayısının karekökü 3162.2776601683795 ' dir

# %%
def  f(x):

    x= x**(1/2)

    return x

print(f(19))
# Out:
# 4.358898943540674

# %%
#  1 den üst limite kadar olan sayıların karelerinin toplamı

ust_limit= int(input("bir ust limit değeri giriniz"))

toplam=0
sayaç=0

for i in range(1,ust_limit+1):

    sayaç+= 1
    toplam= toplam+ sayaç**2

    print("1 den ",sayaç," e kadar olan syaıların kareleri toplamı =",toplam)
# Out:
# 1 den  1  e kadar olan syaıların kareleri toplamı = 1
# 1 den  2  e kadar olan syaıların kareleri toplamı = 5
# 1 den  3  e kadar olan syaıların kareleri toplamı = 14
# 1 den  4  e kadar olan syaıların kareleri toplamı = 30
# 1 den  5  e kadar olan syaıların kareleri toplamı = 55
# 1 den  6  e kadar olan syaıların kareleri toplamı = 91
# 1 den  7  e kadar olan syaıların kareleri toplamı = 140
# 1 den  8  e kadar olan syaıların kareleri toplamı = 204
# 1 den  9  e kadar olan syaıların kareleri toplamı = 285
# 1 den  10  e kadar olan syaıların kareleri toplamı = 385
# 1 den  11  e kadar olan syaıların kareleri toplamı = 506
# 1 den  12  e kadar olan syaıların kareleri toplamı = 650
# 1 den  13  e kadar olan syaıların kareleri toplamı = 819
# 1 den  14  e kadar olan syaıların kareleri toplamı = 1015
# 1 den  15  e kadar olan syaıların kareleri toplamı = 1240
# 1 den  16  e kadar olan syaıların kareleri toplamı = 1496
# 1 den  17  e kadar olan syaıların kareleri toplamı = 1785
# ...

# %%
#  bir okuldaki yaş ortalamasını hesaplayan bir program yazalamım


okul_mevcudu = int(input("okul mevcudunu giriniz"))

for i in range ( okul_mevcudu  ):


    okuldaki_top_yaş = int(input("yaş giriniz"))

yaş_ort = okul_mevcudu/ okuldaki_top_yaş

print("okuldaki",okul_mevcudu," kişinin kişinin yaş ortalaması =",yaş_ort,' kadardır')
# Out:
# okuldaki 3  kişinin kişinin yaş ortalaması = 0.05357142857142857  kadardır

# %%
#  7 basamaklı sayıların 3 basamklı sayılara bölümü

yedi_bas= input(" 7 basamaklı bir sayı giriniz!")

if int(len(yedi_bas)) == 7:

    üç_bas = input("3 basamaklı bir sayı giriniz")

    
    if int(len(üç_bas)) == 3:

        sonuç= int(yedi_bas / üç_bas)

        print(sonuç)

    else:

        print(" girdiniz sayı 3 basamaklı olmalıdır")


else:
    print("girdiğiniz sayı 7 basamaklı değil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[43], line 12
#       7 üç_bas = input("3 basamaklı bir sayı giriniz")
#      10 if int(len(üç_bas)) == 3:
# ---> 12     sonuç= int(yedi_bas / üç_bas)
#      14     print(sonuç)
#      16 else:
#
# TypeError: unsupported operand type(s) for /: 'str' and 'str'

# %%
sayı =int(input(" sayı giriniz"))
sayı2 = int(input("2. sayıyı giriniz"))

toplam = sayı + sayı2

print("sayıların toplamı" ,toplam )

çarpım = sayı* sayı2

print("sayıların çarpımı",çarpım)
# Out:
# sayıların toplamı 35
# sayıların çarpımı 276

# %%
# aamacımız diskirimanant hesaplayan bir program yazmak 

a = int(input("bir a değeri giriniz"))
b= int(input(" bir b sayı değeri giriniz"))
c = int (input(" bir c değeri giriniz"))

diskiriminant = (b**2) - (4*a*c)
print(diskiriminant)
# Out:
# -3468

# %%
sayaç=0
toplam=0

for i in range(1,100):
    sayaç= sayaç+1
    toplam= toplam + sayaç

    print(toplam)
# Out:
# 1
# 3
# 6
# 10
# 15
# 21
# 28
# 36
# 45
# 55
# 66
# 78
# 91
# 105
# 120
# 136
# 153
# 171
# 190
# 210
# 231
# 253
# 276
# 300
# 325
# 351
# 378
# 406
# 435
# 465
# 496
# 528
# 561
# 595
# 630
# 666
# 703
# 741
# 780
# 820
# 861
# 903
# 946
# 990
# 1035
# 1081
# 1128
# 1176
# 1225
# 1275
# 1326
# 1378
# 1431
# 1485
# 1540
# 1596
# 1653
# 1711
# 1770
# 1830
# 1891
# 1953
# 2016
# 2080
# 2145
# 2211
# 2278
# 2346
# 2415
# 2485
# 2556
# 2628
# 2701
# 2775
# 2850
# 2926
# 3003
# 3081
# 3160
# 3240
# 3321
# 3403
# 3486
# 3570
# 3655
# 3741
# 3828
# 3916
# 4005
# 4095
# 4186
# 4278
# 4371
# 4465
# 4560
# 4656
# 4753
# 4851
# 4950

# %%
n = int(input("bir n sayı değeri giriniz"))
for i in range (1,n,2):
    toplam = toplam +i

    print(toplam)
# Out:
# 203

# %%
n = int(input("bir n sayı değeri giriniz"))

toplam=0
for i in range(n+1):

 if i % 2==1 :
  
  toplam= toplam +i
  print( "1 den ",n ,"e kadar olan sayıların toplamı",toplam , end=" ")
# Out:
# 1 den  1 e kadar olan sayıların toplamı 1

# %%
#  1 den üst limite kadar olan tek ayıların toplamı

ust_limit= int(input(" bir üst limit değeri giriniz"))

sayaç=1
toplam=0

while sayaç <= ust_limit:

    toplam = toplam+ sayaç
    sayaç= sayaç + 2
    print(toplam , end= "  ")
# Out:
# 1  4

# %%
#  birden üstlimite kadar olan çift sayıların toplamı

ust_limit= int(input(" bir üst limit değeri giriniz"))

sayaç=0
toplam=0

while sayaç <= ust_limit:

    toplam = toplam+ sayaç
    sayaç= sayaç + 2
    print(toplam , end= "  ")
# Out:
# 0  2  6  12  20  30  42  56  72  90  110  132  156  182  210  240  272  306  342  380  420  462  506  552  600  650  702  756  812  870  930  992  1056  1122  1190  1260  1332  1406  1482  1560  1640  1722  1806  1892  1980  2070  2162  2256  2352  2450  2550

# %%
def polindrommu(x):

    y = x[::-1]

    if x==y :
        
      return True
    
    else:
       return False
    
print(polindrommu("16761"))
# Out:
# True

# %%
#  polindrommudur
isim= input("ismininizi girin")

isim1 = isim[::-1]

if isim ==isim1:
    print(isim," bir polindromdur")

else :
    print(isim,"bir polindrom değil")
# Out:
# evren bir polindrom değil

# %%
# sesli ve sessiz harf sayısı

isim_soyisim = str(input("isim ve soyisiminizi girin"))

sayaç=0

sesli_harf= "a e i ı o ö u ü"

for harf in isim_soyisim:
    if harf in sesli_harf:
        sayaç = sayaç+1
        
        print("sesli harf sayısı",sayaç,end=",")

        a = len(isim_soyisim)

        sessiz_harf= a - sayaç

        print("sessiz harf sayısı",sessiz_harf)
# Out:
# sesli harf sayısı 1,sessiz harf sayısı 3
# sesli harf sayısı 2,sessiz harf sayısı 2

# %%
sayı= int(input("bir sayı giriniz"))

for i in range(2,sayı):



  if sayı % i ==0:
    print(sayı,"asal sayı değil")
    
    break

  else:
     print(sayı,"asal sayı ")
     break
# Out:
# 8954045453421111 asal sayı

# %%
kaç_sayı = int(input("kaç sayı gireceksiniz"))

tek_sayaç= 0
çift_sayaç=0

while kaç sayı 

   
   if i % 2 == 1:
    tek_sayaç= tek_sayaç + 1

    print(tek_sayaç)

   else:
     çift_sayaç = çift_sayaç+1
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[5], line 6
#       3 tek_sayaç= 0
#       4 çift_sayaç=0
# ----> 6 for i in range (kaç_sayı) == int(input("sayı gir")) :
#       9    if i % 2 == 1:
#      10     tek_sayaç= tek_sayaç + 1
#
# TypeError: 'bool' object is not iterable

# %%
s= 0
tek_sayaç=0
çift_sayaç=0
tek_toplam= 0
çift_toplam = 0


for i in range (1,11):
    s = int(input("10 tane tam sayı giriniz"))
  
    if i%2==0:

        çift_sayaç= çift_sayaç +1
        çift_toplam= çift_toplam +s
        çift_ortalam = çift_toplam/ çift_sayaç

    else :
        tek_sayaç= tek_sayaç +çift_toplam
        tek_toplam= tek_toplam +s


print("tek sayı sayısı",tek_toplam, çift_ortalam)
print("çift sayı sayısı",çift_toplam)
# Out:
# tek sayı sayısı 20 6.6
# çift sayı sayısı 33
