# %%
print("hello world")
# Out:
# hello world

# %%
a=2
b= a+4
a=a+7

print(a ,b)

z = a**b
print(z)
# Out:
# 9 6
# 531441

# %%
msg = "benim adım"+ "kctrk"

# %%
print(msg)
# Out:
# benim adımkvtrk

# %%
# boolean doğru yada yanlıiı ifade eder      and ve    or veyayı ifade etmek için kullanılır
True and False
# Out:
# False

# %%
False and True
# Out:
# False

# %%
True or False
# Out:
# True

# %%
not False
# Out:
# True

# %%
a=3
a<5
# Out:
# True

# %%
#  if, else if doğru    else ise yanlışları ifade etmektrdir

a=10
b=21

if a<b:
    print( "a b den küçük")

else :
    print( "b a dan büyük")
# Out:
# a b den küçük

# %%
if a>b:
    print("x")
print("z")

print("y")
# Out:
# z
# y

# %%
# eşittir işaretini parantezin iç tarafına koymamız gerekir

if (a > b) or (a <= b):
   print("x")
   print("y")

print("z")
# Out:
# x
# y
# z

# %%
yas=19

if yas<15:
    print("sen daha çocuksun")

if yas>15:
     print("sen daha gençsin")
# Out:
# sen daha gençsin

# %%
#  if yanlış ise else geçer ve onu tanımlar


yas=37

if  yas>40:
    print("yaşın 40 dan büyük")

else:
     print("yaşın 40 dan büuük vaya eşit")
# Out:
# yaşın 40 dan büuük vaya eşit

# %%
a=5
b=7

if a<b:
    print(2*a)

else:
    print(3*b)
# Out:
# 10

# %%
#  bu soruda ayı 5 b yi ise yedi olarak tanımlamaktadır

if a<b:
    print("a b den küçük")
    if a+5 < b:
        print(" a b den çok küçük")
    
    else :
        print("a b ye yakın")
else:
    a==b

    print( b )
# Out:
# a b den küçük
#  a b den çok küçük

# %%
#  == sembolü bu kodda ilk olarak a bye eşitmi daha sonra ise a b nin iki katına eşitmi onu anlamıza yardımcı olmuştur

a ,b = 12, 6
if a<b:
    print("a b den küçük")
    if(a+5)<b:
        print("a b den çok kuçük")

    else:
        print("a b ye yakın")
else:
    print("a b den küçük değil")

    if a== b*2:
        print(" a b nin iki katıdır")
# Out:
# a b den küçük değil
#  a b nin iki katıdır

# %%
a=4 
b=2 
if a==b:
    print("a b ye eşittir")
else:
    if a==b*3:
        print("a b nin 3 katıdır")

    else:
        print("a b ye eşit değildir ve a b nin 3 katıda değildir")
# Out:
# a b ye eşit değildir ve a b nin 3 katıda değildir

# %%
a=7
b=21
if a==b:
    print("a")
      
else  :
    a==b*3
    print("a b nin 3 katıdır")
# Out:
# a b nin 3 katıdır

# %%
"""bu ifade şu anşama gelmektedir: eğer a bye eşit ise A yazdır
   a b ye eşit değil ve a bnin 3 katı ise a b nin 3 katıdır yazdır
   değilse a b ye eşit değil a b nin 3 katıda değildir yazdıe
   """
a=21
b=7


if a==b:
    print("A")
      

elif a==b*3:
      print("a b nin 3 katıdır")

else:
     print("a b ye eşit değildir ve a b nin 3 katıda değildir")
# Out:
# a b nin 3 katıdır

# %%
# bir ifade yanlıila başlıyor ve and diye devam ediyorsa if bunu okumaz çünkü ifade yanlışdır


n=3
x=0
y=7

if (y<0) and (y>x):
    x=y

print(x)
# Out:
# 0

# %%
n=3
x=-7
y=-5

if (y<0) and (y>x):
    x=y

print(x)
# Out:
# -5

# %%
not1=80
not2=60
not3=10

toplam= not1+ not2 +not3
ortalama = toplam/3 

print(ortalama)

if ortalama >=80:
    print ("notumuz AA")

elif ortalama >=55:
    print("ortalama cd")

else :
    print("kaldınn")
# Out:
# 50.0
# kaldınn
