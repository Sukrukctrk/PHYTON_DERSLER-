# %%
# Bu projede ise 4 tane sınıfı oluşturun.

# Hayvan Sınıfı ------> Bütün hayvanların ortak özelliklerinin toplandığı sınıf olacak.

# Köpek Sınıfı ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa köpeklere ait ek özellikler ve metodlar ekleyin.

# Kuş Sınıfı ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa kuşlara ait ek özellikler ve metodlar ekleyin.

# At Sınıfı ------> Bu sınıf, hayvan sınıfından miras alan bir sınıf olacak. Ayrıca bu sınıfa atlara ait ek özellikler ve metodlar ekleyin.


class hayvan():
    def __init__(self,tür,renk,bacak_sayısı,ortalama_yaşam) :

        self.tür=tür
        self.renk=renk
        self.bacak_sayısı=bacak_sayısı
        self.ortalama_yaşam=ortalama_yaşam

    def tür_değiştir(self,yeni_tür):

        self.tür=yeni_tür
    def renk_değiştir(self,yeni_renk):
        self.renk=yeni_renk

    def bacak_sayısı_d(self,yeni_bacak_sayısı):

        self.bacak_sayısı=yeni_bacak_sayısı

    def ortalama_y_D(self,yeni_ortalama_y):
        self.ortalama_yaşam=yeni_ortalama_y

# %%
hayvan=hayvan("memeli","siyah",4,"2 yıl")

# %%
hayvan.ortalama_yaşam
# Out:
# '2 yıl'

# %%
class köpek(hayvan):
       pass

# %%
köpek=köpek("memeli","siyah",4,"2 yıl")

# %%
köpek.ortalama_yaşam
# Out:
# '2 yıl'

# %%
class köpek(hayvan):

    def __init__(self,tür,ortalama_yaşam,renk,bacak_sayısı,cins):
        
  
        self.tür=tür
        self.renk=renk
        self.bacak_sayısı=bacak_sayısı
        self.ortalama_yaşam=ortalama_yaşam
        self.cins=cins

# %%
köpek=köpek("köpek","4 sene","siyah","4","pitbul")

# %%
köpek.cins
# Out:
# 'pitbul'

# %%
class hayvan():
    def __init__(self,tür,renk,bacak_sayısı,ortalama_yaşam) :

        self.tür=tür
        self.renk=renk
        self.bacak_sayısı=bacak_sayısı
        self.ortalama_yaşam=ortalama_yaşam

    def tür_değiştir(self,yeni_tür):

        self.tür=yeni_tür
    def renk_değiştir(self,yeni_renk):
        self.renk=yeni_renk

    def bacak_sayısı_d(self,yeni_bacak_sayısı):

        self.bacak_sayısı=yeni_bacak_sayısı

    def ortalama_y_D(self,yeni_ortalama_y):
        self.ortalama_yaşam=yeni_ortalama_y

# %%
class at(hayvan):
    pass

# %%
class at(hayvan):

    def  __init__(self,tür,ortalama_yaşam,renk,bacak_sayısı,hızı):
         super.__init__(tür,ortalama_yaşam,renk,bacak_sayısı)

         self.hızı=hızı
# Out:
# Geçerli hücrede veya önceki bir hücrede kod yürütülürken Çekirdek kilitlendi.
#
# Hatanın olası nedenini belirlemek için lütfen hücrelerdeki kodu inceleyin.
#
# Daha fazla bilgi için <a href='https://aka.ms/vscodeJupyterKernelCrash'>buraya</a> tıklayın.
#
# Daha fazla ayrıntı için Jupyter <a href='command:jupyter.viewOutput'>günlüğüne</a> bakın.

# %%
at = at("at","10 yıl","beyaz",4,100 )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[63], line 1
# ----> 1 at = at("at","10 yıl","beyaz",4,100 )
#
# Cell In[60], line 4, in at.__init__(self, tür, ortalama_yaşam, renk, bacak_sayısı, hızı)
#       3 def  __init__(self,tür,ortalama_yaşam,renk,bacak_sayısı,hızı):
# ----> 4      super.__init__(tür,ortalama_yaşam,renk,bacak_sayısı)
#       6      self.hızı=hızı
#
# TypeError: descriptor '__init__' requires a 'super' object but received a 'str'

# %%
# Proje 2
# Bir tane "Bilgisayar" sınıfı oluşturarak bu sınıfa metodlar ve özellikler ekleyin ve bu class'ı kullanmaya çalışın.

# Bu sınıfı yazarken öğrendiğimiz özel metodların hepsini tanımlamaya çalışın.

# %%
class bilgisayar():

    def __İnit__(self,işlemci,ram,ekran_kartı,ssd,işletim_sistemi):

        self.ram=ram
        self.işlemci=işlemci
        self.ekran_kartı=ekran_kartı
        self.ssd=ssd
        self.işletim_sistemi=işletim_sistemi

    def kullanıcı_bilgileri(self):

        print("""
         
        bilgisayar  bilgileri
              
              1. işlemci :{}
              2. ram :{}
              3. ekran_kartı:{}
              4: ssd: {}
              5  işletim_sistemi: {}


             """.format(self.işlemci,self.ram,self.ekran_kartı,self.ssd,self.işletim_sistemi))

# %%
bilgisayar1=bilgisayar()

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 bilgisayar1.kullanıcı_bilgileri()
#
# Cell In[5], line 24, in bilgisayar.kullanıcı_bilgileri(self)
#      11 def kullanıcı_bilgileri(self):
#      13     print("""
#      14
#      15     bilgisayar  bilgileri
#      16
#      17           1. işlemci :{}
#      18           2. ram :{}
#      19           3. ekran_kartı:{}
#      20           4: ssd: {}
#      21           5  işletim_sistemi: {}
#      22
#      23
# ---> 24          """.format(self.işlemci,self.ram,self.ekran_kartı,self.ssd,self.işletim_sistemi))
#
# AttributeError: 'bilgisayar' object has no attribute 'işlemci'
