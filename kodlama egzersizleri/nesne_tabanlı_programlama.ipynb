# %%
class araba():
    renk = "mavi"
    model= "passat"
    beygir= "200"

# %%
araba1= araba

# %%
araba.model
# Out:
# 'passat'

# %%
araba.model
# Out:
# 'passat'

# %%
dir(araba)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'beygir',
#  'model',
#  'renk']

# %%
class araba():
    renk = "mavi"
    model= "passat"
    beygir= "200"

  

    def __init__(self):
        print("init fonksiyonu çağrıldı")

# %%
araba1=araba()
# Out:
# init fonksiyonu çağrıldı

# %%
class araba():
   


    def __init__(self):
        print("init fonksiyonu çağrıldı")

        self.model = model
        self.renk=  renk
        self.beygir= beygir

# %%
araba1= araba("renualt","mavi","200")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 araba1= araba("renualt","mavi","200")
#
# TypeError: araba.__init__() takes 1 positional argument but 4 were given
