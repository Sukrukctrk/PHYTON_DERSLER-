# %%
#  Kullanıcıdan alınan boy ve kilo değerlerine göre beden kitle indeksini hesaplayın ve şu kurallara göre ekrana şu yazıları yazdırın.

#  Beden Kitle İndeksi: Kilo / Boy(m) *  Boy(m)

#  BKİ 18.5'un altındaysa -------> Zayıf

#  BKİ 18.5 ile 25 arasındaysa ------> Normal

#  BKİ 25 ile 30 arasındaysa --------> Fazla Kilolu

#  BKİ 30'un üstündeyse -------------> Obez


kilo = int(input("kilonuzu giriniz"))
boy = int (input("boyunuzu  metre cinsinden giriniz"))

bki =kilo/ boy*boy

if bki <= 18.5:
    print("zayıf")

elif  bki >18.5 and bki<= 25:
     print("normal")

elif bki> 25 and bki<=30:
     print("fazla kilo")

else:
     print("obez")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[11], line 15
#       1 #  Kullanıcıdan alınan boy ve kilo değerlerine göre beden kitle indeksini hesaplayın ve şu kurallara göre ekrana şu yazıları yazdırın.
#       2
#       3 #  Beden Kitle İndeksi: Kilo / Boy(m) *  Boy(m)
#    (...)
#      10
#      11 #  BKİ 30'un üstündeyse -------------> Obez
#      14 kilo = int(input("kilonuzu giriniz"))
# ---> 15 boy = int (input("boyunuzu  metre cinsinden giriniz"))
#      17 bki =kilo/ boy*boy
#      19 if bki <= 18.5:
#
# ValueError: invalid literal for int() with base 10: '1.80'

# %%
# Kullanıcıdan 3 tane sayı alın ve en büyük sayıyı ekrana yazdırın.
a= int(input("1. sayıyı gir"))
b= int(input("2. sayıyı giriniz"))
c= int(input("3. sayıyı giriniz"))

if a<b and b<c :
    print("en büyük sayı ",c,"dir")

elif a<b and c<b :
    print("en büyük sayı",b,"dir")

else:
    print("en büyük asyı",a,"dır")
# Out:
# en büyük sayı  56 dir

# %%
#  2. dereceden bir bilinmeyenli denklemin köklerini bulma      ax**2 +bx +c
#  delta= b**2 -4ac       

a= int(input("bir a değeri giriniz"))
b = int(input("bir b değeri giriniz"))
c= int(input("bir c değeri giriniz"))

delta = (b**2) -(4*a*c)

kök1= (-b -(delta**1/2))/2*a
kök2= (-b +(delta**1/2))/2*a

print("kök1=",kök1)
print("kök2",kök2)
# Out:
# kök1= 18.0
# kök2 -30.0

# %%
# Kullanıcıdan iki tane sayı isteyin ve bu sayıların değerlerini birbirleriyle değiştirin.

a= int(input("bir a tam sayısı giriniz"))
b= int(input("bir be tam sayısı giriniz"))

a,b =b,a

print(a,b)
# Out:
# 2 12

# %%
#  bankamatik kodu


işlem1= "para yatırma"
işlem2 = "bakiye sorgulama"
işlem3= "para çekme"
işlem4= "çıkış"

while True:
    işlem= input(" hoşgeldiniz yapmak istediniz işlemi giriniz")

    if işlem==işlem1:
        miktar= int(input("yatırmak istediniz miktarı giriniz"))
        print(miktar,"tl başarıyla yatırılmıştır")

    if işlem2== işlem:
        print("1200 tl bakiyeniz bulunmaktadır")

    if işlem3==işlem:
        çekilen_para =int(input("çekmek isdeniz miktarı giriniz"))
       
        print(çekilen_para,"tl başarıyla çekilmiştir")

    else:
        print("çıkış yapılıyor")
        break
# Out:
# 1200 tl başarıyla çekilmiştir
# çıkış yapılıyor

# %%
#  kullanıcı girişi programı bu programı geliştir
giriş_hakkı= 3

while True:

    isim= input("kullanıcı adınızı giriniz")
    parola= input("6 haneli parolanızı giriniz")

    if isim== "sukru" and parola == 173843:
        print("giriş yapılıyor")

    else:
        print("hatalı giriş")
        
        giriş_hakkı= giriş_hakkı-1

        if  giriş_hakkı== 0 :
            print("max denem sayısına ulaştınız")
            break
# Out:
# hatalı giriş
# hatalı giriş
# hatalı giriş
# max denem sayısına ulaştınız

# %%
#  faktöriyel bulma programı

toplam= 1
sayaç=1


sayı= int(input("bir sayı giriniz"))

while sayaç<=sayı:
    
    if sayı> 1:
    
     toplam= sayaç*toplam
     sayaç= sayaç +1


     
   
     print(toplam)

    elif sayı==1 or sayı==0:
       print(sayı,"faktörüyel =",toplam)
       break

    else: 
       sayı<0

       print("sayı negatif olamaz")
       
       break
# Out:
# 1
# 2

# %%
#  fiboccani sayı dizisini oluşturalım

toplam=1
sayaç=0

sayı= int(input("bir sayı değeri giriniz"))

while sayı<= sayaç:
    
  
  toplam= toplam*sayaç
  sayaç= sayaç+1
    
  print(toplam)

# %%
#  fiboccani sayı dizisini oluşturalım

toplam=1
sayaç=1

sayı= int(input("bir sayı değeri giriniz"))

while sayı<= sayaç:
    
  
  toplam= toplam*sayaç
  sayaç= sayaç+1
    
  print(toplam)

# %%
#  bir sayı mükemmelmi değilmi kendi haç pozitif bölenleri toplamı bu asyıya eşitse bu sayı mükemmel bir sayıdır
sayı= int(input("bir sayı giriniz"))
i=1

toplam=0
while sayı>= i:
 
 
    i=i+1

    if sayı%i ==0:
        toplam=toplam+i

if toplam== sayı:
    print("mükemmel sayı")

else:
     print("mükemmel sayı değil")
# Out:
# mükemmel sayı değil

# %%
# Kullanıcıdan aldığınız bir sayının "Armstrong" sayısı olup olmadığını bulmaya çalışın.

# Örnek olarak, Bir sayı eğer 4 basamaklı ise ve oluşturan rakamlardan herbirinin 4. kuvvetinin toplamı( 3 basamaklı sayılar için 3.kuvveti ) o sayıya eşitse bu sayıya "Armstrong" sayısı denir.

# Örnek olarak : 1634 = 1^4 + 6^4 + 3^4 + 4^4

sayı =input("bir sayı giriniz")
basamak_sayısı=len(sayı)
sayı=int(sayı)

if basamak_sayısı==1:
    if sayı[0]**1==sayı:

     print("armstrong sayı")
     
    else:
       print("armstrong sayı değil")



elif basamak_sayısı==2:
    if int(sayı[0])**2 + int(sayı[1])**2 == sayı:

     print("armdtrong sayı")

    else:
       print("armstrong sayı değil")


elif basamak_sayısı==3:
   if  sayı[0]**3 + sayı[1]**3+ sayı[2]**3==sayı:

    print("armstrongsayı")


   else:
       print("armstrong sayı değil")


 
elif basamak_sayısı==4:
   if  sayı[0]**4 + sayı[1]**4+ sayı[2]**4 + sayı[3]**4 ==sayı:

    print("armstrongsayı")


   else:
       print("armstrong sayı değil")      




elif basamak_sayısı==5:
   if  sayı[0]**5 + sayı[1]**5+ sayı[2]**5+ sayı[3]**5 +sayı[4]**5==sayı:

    print("armstrongsayı")


   else:
       print("armstrong sayı değil")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[64], line 22
#      17        print("armstrong sayı değil")
#      21 elif basamak_sayısı==2:
# ---> 22     if int(sayı[0])**2 + int(sayı[1])**2 == sayı:
#      24      print("armdtrong sayı")
#      26     else:
#
# TypeError: 'int' object is not subscriptable

# %%
# 1'den 100'e kadar olan sayılardan sadece 3'e bölünen sayıları ekrana bastırın. Bu işlemi *continue* ile yapmaya çalışın

for i in range(1,100):
   if i%3 == 0:

    print(i,end=" ")
# Out:
# 3 6 9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72 75 78 81 84 87 90 93 96 99

# %%
for i in range(1,101):
    
    if (i % 3 != 0):
        continue
    print(i,end=" ")
# Out:
# 3 6 9 12 15 18 21 24 27 30 33 36 39 42 45 48 51 54 57 60 63 66 69 72 75 78 81 84 87 90 93 96 99

# %%
# Kullanıcıdan 2 basamaklı bir sayı alın ve bu sayının okunuşunu bulan bir fonksiyon yazın.

# Örnek: 97 ---------> Doksan Yedi



birler =["","bir","iki","üç","dört","beş","altı","yedi","sekiz","dokuz"]
onlar =["","on","yirmi","otuz","kırk","elli","altmış","yetmiş","seksen","doksan"]

def okunus(sayı):

    birinci = sayı % 10
    ikinci = sayı // 10
    
    return onlar[ikinci] + " " + birler[birinci]

    
sayı =  int(input("Sayı:"))

print(okunus(sayı))
# Out:
# yirmi dört

# %%
# Kullanıcıdan 2 tane sayı alarak bu sayıların en küçük ortak katlarını (EKOK) dönen bir tane fonksiyon 


def ekok(sayı ,sayı2):

 if sayı== sayı2:
  return sayı
  
 else:
  for i in range
# Out:
#   Cell In[8], line 10
#     for i in range
#                    ^
# SyntaxError: expected ':'

# %%
# 1'den 100'e kadar olan sayılardan pisagor üçgeni oluşturanları ekrana yazdıran bir fonksiyon yazın.(a <= 100,b <= 100)

def pisagor_bulma():
    
    pisagor_listesi = list()
    for i in range(1,101):
        for j in range(1,101):

            c = (i ** 2 + j ** 2) ** 0.5

            if (c == int(c) ):
                pisagor_listesi.append((i,j,int(c)))

    return pisagor_listesi

for i in pisagor_bulma():
    print(i)
# Out:
# (3, 4, 5)
# (4, 3, 5)
# (5, 12, 13)
# (6, 8, 10)
# (7, 24, 25)
# (8, 6, 10)
# (8, 15, 17)
# (9, 12, 15)
# (9, 40, 41)
# (10, 24, 26)
# (11, 60, 61)
# (12, 5, 13)
# (12, 9, 15)
# (12, 16, 20)
# (12, 35, 37)
# (13, 84, 85)
# (14, 48, 50)
# (15, 8, 17)
# (15, 20, 25)
# (15, 36, 39)
# (16, 12, 20)
# (16, 30, 34)
# (16, 63, 65)
# (18, 24, 30)
# (18, 80, 82)
# (20, 15, 25)
# (20, 21, 29)
# (20, 48, 52)
# (20, 99, 101)
# (21, 20, 29)
# (21, 28, 35)
# (21, 72, 75)
# (24, 7, 25)
# (24, 10, 26)
# (24, 18, 30)
# (24, 32, 40)
# (24, 45, 51)
# (24, 70, 74)
# (25, 60, 65)
# (27, 36, 45)
# (28, 21, 35)
# (28, 45, 53)
# (28, 96, 100)
# (30, 16, 34)
# (30, 40, 50)
# (30, 72, 78)
# (32, 24, 40)
# (32, 60, 68)
# (33, 44, 55)
# (33, 56, 65)
# (35, 12, 37)
# (35, 84, 91)
# (36, 15, 39)
# (36, 27, 45)
# (36, 48, 60)
# (36, 77, 85)
# (39, 52, 65)
# (39, 80, 89)
# (40, 9, 41)
# (40, 30, 50)
# (40, 42, 58)
# (40, 75, 85)
# (40, 96, 104)
# (42, 40, 58)
# (42, 56, 70)
# (44, 33, 55)
# (45, 24, 51)
# ...
