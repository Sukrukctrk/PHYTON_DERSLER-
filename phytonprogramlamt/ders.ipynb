# %%
a=5

print(a)
# Out:
# 5

# %%
a= int (input("lutfen bir sayi girin"))
print(a)
# Out:
# 5

# %%
import math

a=math.factorial(5)
print(a)
# Out:
# 120

# %%
a= int(input("lutfen bir sayi giriniz"))


print("girdiginiz sayinin 2 ile bölmünden kalan :",a%2)
# Out:
# girdiginiz sayinin 2 ile bölmünden kalan : 1

# %%
int(3.14)
# Out:
# 3

# %%
ord('A')
#  ord bir karakteri sayıya sayıyıda karaktere dönüştürür
# Out:
# 65

# %%
"abcdsggsftfs"[2:4]  
# 3 ve 4 üncü karakteri yazdır
# Out:
# 'cd'

# %%
"asvcggafsdg"[-1]
#  sondaki karakteri basar
# Out:
# 'g'

# %%
"sgvdhsgvcghv"[-2]
# Out:
# 'h'

# %%
len("hi")
# uzunluk
# Out:
# 2

# %%
"sukru"[::-1]
# Out:
# 'urkus'

# %%
"sukru kocaturk"[::-2]
# Out:
# 'kuao ru'

# %%
"Hİ".lower()
#  KÜÇÜK OLARAK BASAR
# Out:
# 'hi̇'

# %%
"sgdgjsdgvbsddhfvb".split("b")
#  parçalamamızı sağar
# Out:
# ['sgdgjsdgv', 'sddhfv', '']

# %%
"s" in "sukru"
# Out:
# True

# %%
a=(1,2,"sukru")
type(a)
# Out:
# tuple

# %%
a=(1,2,"sukru")
type(a)
a.count(1)

#  bir kaç defa geçiyor
# Out:
# 1

# %%
a=[1,2,3,4,5]
a.append(8)

print(a)
#  append sonuna elaman eklemeyi sağlar
# Out:
# [1, 2, 3, 4, 5, 8]
